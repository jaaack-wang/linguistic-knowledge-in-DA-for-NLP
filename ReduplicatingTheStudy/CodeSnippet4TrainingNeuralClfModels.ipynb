# %%
net = 'gru'
train_set_suffix = '_50k_aug_reda_ngram'
train_set_path = './train' + train_set_suffix + '.txt'

# %%
# !python -m paddle.distributed.launch --gpus "0" train.py --vocab_path='./vocab.txt' \
   --train_set_path={train_set_path} \
   --dev_set_path='./dev.txt' \
   --device=gpu \
   --network={net} \
   --lr=5e-4 \
   --batch_size=64 \
   --epochs=3 \
   --save_dir='./checkpoints'
# Out:
# -----------  Configuration Arguments -----------
# gpus: 0
# heter_worker_num: None
# heter_workers:
# http_port: None
# ips: 127.0.0.1
# log_dir: log
# nproc_per_node: None
# run_mode: None
# server_num: None
# servers:
# training_script: train.py
# training_script_args: ['--vocab_path=./vocab.txt', '--train_set_path=./train_50k_aug_reda_ngram.txt', '--dev_set_path=./dev.txt', '--device=gpu', '--network=gru', '--lr=5e-4', '--batch_size=64', '--epochs=3', '--save_dir=./checkpoints']
# worker_num: None
# workers:
# ------------------------------------------------
# WARNING 2021-11-23 06:12:37,337 launch.py:359] Not found distinct arguments and compiled with cuda or xpu. Default use collective mode
# launch train in GPU mode!
# INFO 2021-11-23 06:12:37,338 launch_utils.py:510] Local start 1 processes. First process distributed environment info (Only For Debug):
#     +=======================================================================================+
# ...

# %%
# !CUDA_VISIBLE_DEVICES=0 python predict.py --vocab_path='./vocab.txt' \
   --test_set_path='./test.txt' \
   --train_set_suffix={train_set_suffix} \
   --out_dir='./tests_pred/' \
   --device=gpu \
   --network={net} \
   --params_path='./checkpoints/final.pdparams'
# Out:
# W1123 06:26:33.915802  3550 device_context.cc:404] Please NOTE: device: 0, GPU Compute Capability: 7.0, Driver API Version: 11.0, Runtime API Version: 10.1
# W1123 06:26:33.919893  3550 device_context.cc:422] device: 0, cuDNN Version: 7.6.
# Loaded parameters from ./checkpoints/final.pdparams
# Accuracy:  0.645
# The predictions for ./test.txt have been saved in ./tests_pred/test_50k_aug_reda_ngram_gru_predictions.txt
